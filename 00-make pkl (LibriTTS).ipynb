# %%
import os
# import pickle
import _pickle as cPickle
import gc
import random
from tqdm import tqdm
import numpy as np
import torch

from datasets import load_dataset, load_metric
import math
from itertools import groupby

import wandb

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
os.environ["WANDB_DISABLED"] = "true"

cache_dir = "/data4/yoomcache"
model_cache_dir = os.path.join(cache_dir, 'huggingface')
data_cache_dir = os.path.join(cache_dir, 'datasets')
checkpoint_dir = os.path.join(cache_dir, 'checkpoint')

seed = 0
random.seed(0)
np.random.seed(seed)
torch.manual_seed(seed)

import IPython
import seaborn as sns
sns.set(rc = {'figure.figsize':(16,8)})

# %%
data_dir = '/data4/TTS/'
# data_fname = 'VCTK-Corpus/dataset-vctk-16k.pkl'
# data_fname = 'LibriTTS/train-clean-100.pkl'
data_fname = 'LibriTTS/dev-clean.pkl'

with open(os.path.join(data_dir, data_fname), 'rb') as f:
    gc.disable()
    dataset = cPickle.load(f)
    gc.enable()

print('entire dataset length: {}'.format(len(dataset['text'])))

for k in dataset.keys():
    if k == 'sample_rate': continue
    del dataset[k][int(len(dataset[k])):]
dataset_size = len(dataset['text'])


max_audio_length = 0
for arr in dataset['audio_array'][:dataset_size]:
    if len(arr) > max_audio_length:
        max_audio_length = len(arr)
print('maximum audio length: {}'.format(max_audio_length))
# Out:
# entire dataset length: 5736
# maximum audio length: 481280

# %%
dataset.keys()
# Out:
# dict_keys(['page', 'index', 'audio_path', 'audio_array', 'text', 'sample_rate'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(dataset)

# %%
df.sort_values('index')
# Out:
#        page     index                                         audio_path  \
# 29248  p225  p225_001  /data4/TTS/VCTK/VCTK-Corpus/wav48/p225/p225_00...
# 29279  p225  p225_002  /data4/TTS/VCTK/VCTK-Corpus/wav48/p225/p225_00...
# 29351  p225  p225_003  /data4/TTS/VCTK/VCTK-Corpus/wav48/p225/p225_00...
# 29188  p225  p225_004  /data4/TTS/VCTK/VCTK-Corpus/wav48/p225/p225_00...
# 29307  p225  p225_005  /data4/TTS/VCTK/VCTK-Corpus/wav48/p225/p225_00...
# ...     ...       ...                                                ...
# 29454  p376  p376_291  /data4/TTS/VCTK/VCTK-Corpus/wav48/p376/p376_29...
# 29469  p376  p376_292  /data4/TTS/VCTK/VCTK-Corpus/wav48/p376/p376_29...
# 29437  p376  p376_293  /data4/TTS/VCTK/VCTK-Corpus/wav48/p376/p376_29...
# 29617  p376  p376_294  /data4/TTS/VCTK/VCTK-Corpus/wav48/p376/p376_29...
# 29685  p376  p376_295  /data4/TTS/VCTK/VCTK-Corpus/wav48/p376/p376_29...
#
#                                              audio_array  \
# 29248  [0.0038153944, 0.0069943625, 0.0059126774, 0.0...
# 29279  [-0.0036491496, -0.006820807, -0.0059936647, -...
# 29351  [-0.0028066966, -0.00484558, -0.0038843188, -0...
# 29188  [0.002831708, 0.0052296943, 0.0044813827, 0.00...
# 29307  [0.00010675909, 0.00035040374, 0.00026865466, ...
# ...                                                  ...
# 29454  [-0.0039445944, -0.0070481566, -0.0062631024, ...
# 29469  [0.007278188, 0.013384368, 0.011897836, 0.0127...
# 29437  [-0.0060262484, -0.011149624, -0.009517272, -0...
# 29617  [-0.00473665, -0.008488858, -0.0071424493, -0....
# 29685  [-0.0045092436, -0.008362561, -0.0074372008, -...
#
#                                                     text  sample_rate
# 29248                                Please call Stella.        16000
# 29279  Ask her to bring these things with her from th...        16000
# 29351  Six spoons of fresh snow peas, five thick slab...        16000
# 29188  We also need a small plastic snake and a big t...        16000
# 29307  She can scoop these things into three red bags...        16000
# ...                                                  ...          ...
# 29454  "I have tonight resigned as a member of the Eu...        16000
# 29469  "The move was welcomed by the Roman Catholic C...        16000
# 29437  "That might be a punishment but it would also ...        16000
# 29617                                  "He has retired."        16000
# 29685                      "It became a book by itself."        16000
#
# [44070 rows x 6 columns]

# %%
df.page.unique()
# Out:
# array(['p311', 'p263', 'p251', 'p326', 'p374', 'p340', 'p286', 'p246',
#        'p247', 'p280', 'p302', 'p233', 'p228', 'p335', 'p237', 'p254',
#        'p287', 'p336', 'p298', 'p343', 'p317', 'p273', 'p257', 'p347',
#        'p281', 'p278', 'p360', 'p285', 'p236', 'p271', 'p245', 'p310',
#        'p312', 'p238', 'p297', 'p303', 'p351', 'p250', 'p318', 'p274',
#        'p330', 'p341', 'p306', 'p305', 'p255', 'p288', 'p259', 'p275',
#        'p230', 'p227', 'p276', 'p272', 'p314', 'p268', 'p253', 'p339',
#        'p334', 'p260', 'p231', 'p248', 'p345', 'p249', 'p295', 'p243',
#        'p258', 'p277', 'p252', 'p362', 'p256', 'p229', 'p284', 'p225',
#        'p376', 'p232', 'p262', 'p333', 'p270', 'p239', 'p267', 'p282',
#        'p269', 'p261', 'p234', 'p329', 'p266', 'p364', 'p363', 'p294',
#        'p292', 'p307', 'p293', 'p313', 'p300', 'p299', 'p361', 'p264',
#        'p240', 'p226', 'p241', 'p308', 'p279', 'p304', 'p323', 'p301',
#        'p265', 'p283', 'p244', 'p316'], dtype=object)

# %%
df.loc[df.chapter=='64301', ['index', 'normalized_text']].sort_values('index')

# %%
for page in df.page.unique()[:3]:
    print(page)
    print(' '.join(df.loc[df.page == page, 'text']))
    print()
# Out:
# p311
# They got the job done. We don't ask for much. It is set in Paris. Mentally, you have to be tough. It is not really used by many people. I feel it's time to make the switch. We owe it to the public of Strathclyde. She can scoop these things into three red bags, and we will go meet her Wednesday at the train station. We keep a distance. I was in tears in the street. My position on the euro is quite clear. People look, but no one ever finds it. Eriksson, though, was having none of it. The whole thing has been a nightmare. It's time to say enough is enough. Those Were The Days, indeed. Yet what is supposed to be said? Sadly, in this case, that was not so. We've not won anything yet. They said we were out of touch. And the winners are. I can't believe we didn't win that game. For us, that decision was hard to understand. Awareness in Europe of Scotland is high. It is the whole package. The film has also been superbly designed. They still have the dirty work to do. We are still the best team in Britain. It is quite a new prescription. Sure the COE is a cracking band. I was shaking on the blocks. Only four of his passengers were uninjured. We have reacted well to each other. I agree with them. He said no survivors had been found. There is a solution, she believes. They knew they shouldn't have been there. The whole process was so different. He has one son and one daughter. It ended as it began, in confusion. However, the second goal was about to be delivered. That's what we're still trying to do. We haven't been told. I was delighted with every one of them. I have no battle with the Scots. It's the same as Glasgow. He, too, will return. Johnsen is equally concerned. Throughout the centuries people have explained the rainbow in various ways. But things are never the same again. I'm very frightened of the dark. The Greeks used to imagine that it was a sign from the gods to foretell war or heavy rain. I could do a better job. He looked at me before replying. It is already making a difference. I just did not cope with the pressure. Four minutes later, the show was over. I knew my contract was up this year. What does he want him to look like? It is the end of an era. She has insisted she did nothing wrong. The scientific debate is dead. He was at home with his pals. It wouldn't go off. I am relishing the challenge. This is a big club. After that, the Scottish Parliament will run the show. I was totally wrong. He added that he felt undermined. Yes, it was uplifting. I was furious about it. If that is the perception, that has to be addressed. But don't just take my word, for it. There will be no excuses on Wednesday. Suddenly, the rugby world had changed. Last night, she refused to comment on the accident. Who can say? At least two women were among those arrested. At Westminster, there was disbelief at the news. Can you believe it? He also called in at another farm. She is fulfilled by it. Aristotle thought that the rainbow was caused by reflection of the sun's rays by the rain. I am very happy with life. It doesn't seem like that long ago. I am delighted for Simon. I let go the telephone and ran. It had to be more flexible. The replacements made a big difference. Finally, they have a journey back to their youth. He added, We are not prepared for war. Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob. The party has never fully recovered. It can be halted. This will be no easy option. We think a lot of Allan McGregor. There are two ways to start a festival. You just know it. Everyone is working together to resolve the problems. They did a very good job. He was part of South Africa. However, that is a sizeable if. Which he is, too. These figures are truly terrible. It's a big challenge for the audience. When the sunlight strikes raindrops in the air, they act as a prism and form a rainbow. They didn't find any substance. We will listen to colleagues. They should have listened to me. It was t ...
#
# p263
# I saw the whole thing. We have a free vote on these things in our party. You might not make it. It's too early to say whether a public inquiry would be appropriate. It's just a place to open it. The decision was announced at its annual conference in Dunfermline. Who was she ? I have decided to stand down from the list. The confidence is low, but it is a difficult thing to understand. Losing in that manner is very hard to take. There is a contract in existence for Allan. There is The Beautiful Game to write. Together, we can make a difference. The investment will be in the food. However, he will have his work cut out defending his title. To the Hebrews it was a token that there would be no more universal floods.  Head injuries are the leading cause of death. It was nice to get a clean sheet. He replied that it was a dilemma. It was his conclusion that they were generally in good condition. It goes with the job. The Yugoslav president said he did not recognise the election outcome. John was there already in spirit. The temperature in the town is very difficult to control. However, a ruling will not come before next week. He is married with three children. We must improve our relations with government. We are over the moon. It should have taken a year for a company this size. How are you, sir ? No company would want to put their people at risk. We see the rapid reaction force as the way ahead. It is hard to tell. I told him I was a long time ago. His son has been travelling with the Tartan Army for years. Next time round, it will be different. As it turned out it was a triumph. It was won on the issue of the land. So is that it, then ? They must play for each other. But it is understood to have happened after weeks of arguments. So the Government will be damaged. Tickets will be at a premium. Indeed, it is only the beginning. That all hope is never lost. A progress report will be published in October. Is there a waiting list ? We were not allowed to go to help them. They have to come clean. He's in his element and the audience is delighted by him. I am not interested in the money, it is the principle. There is a range of employers. The advisers had some discussions but no conclusion was reached. Some have accepted it as a miracle without physical explanation.  We were a load of rubbish. I just got under the ball a bit. Nothing has been put into action. My son was too young to die. We have not given up hope. It is a court case. If the red of the second bow falls upon the green of the first, the result is to give a bow with an abnormally wide yellow band, since red and green light when mixed form yellow.  This work on a marketing strategy would be finished within two months. It is still too early for any likely contenders to have emerged. It is the latter which has prompted the warning. Drugs are used a lot at the fishing, not just cannabis. Ask her to bring these things with her from the store.   Many complicated ideas about the rainbow have been formed.  Ms Anderson yesterday put a brave face on the departure. It wouldn't matter if he had. The damage from the fire was huge. Our position remains the same. The irony was not lost. The championship is different from the other majors. I'm so proud to be Scottish tonight. Thomson is expected to manage the business. It's nice to be involved. There is an element of racism in Scotland. I came home by ambulance. He said the Parliament should be left to make its own decision. I have lost all confidence. But the real problem is the closure of the export market. Officers recovered a second body in the area. The first few days will determine whether she can survive. The following year was a miserable time for Mr Dewar. Did he trip ? The Greeks used to imagine that it was a sign from the gods to foretell war or heavy rain.  He was jailed for a year. Chairman Sir Alistair Grant will remain on the board as deputy chairman. The city council is a major property owner in the area. Does that put pres ...
#
# p251
# He thought he had a month to cross the street. I think a move would create a lot of interest. But it failed. Last night was a key episode. The results are sometimes contentious. They do not work for Glasgow City Council. We have to move forward. We have to sort it out ourselves. That's the principal difference between an artist and a dog. They did not replace it with a conviction for culpable homicide. Aristotle thought that the rainbow was caused by reflection of the sun's rays by the rain.  We have a free vote on these things in our party. War is not the action. It is not either national standards or local control. The court was shown a video of the house on that day. You can see it on the training ground and around the hotel. It would still have been a good film, but very different. Despite the result, it was still a great moment. Rebuilding public transport was never going to happen overnight. You are not going in blind. It just shows the arrogance of Labour and the Liberal Democrats. Four other charges were dropped. Friends of the Earth Scotland last night welcomed the announcement. So if we can take anything from tonight, it will be fantastic. Well, you can have a tree. He sets the nature of his Parliament in a simple, realistic context. They had no children. I am immensely sad. Peace was won. It had been played at festivals. Does this mean. It wasn't just the character and energy of the playing. I'd never seen a play about me. It's quite a line-up! I've not thought about it. I saw some terrible things. And the Farmer is worried about another aspect of farming life. In Scotland, we keep the faith. Already, he has been a tremendous influence in the dressing room. Eight months later, he was dead. If the red of the second bow falls upon the green of the first, the result is to give a bow with an abnormally wide yellow band, since red and green light when mixed form yellow.  And if he hadn't become a musician? They thought they had found a home. I am an estate agent. However, this idea is never developed. There's a sense of excess in the novel. It is not like working for a living. I knew he was good. There could be a way back. One knows the feeling. Dewar is certainly under attack from within his own party. Everyone is in favour of the need for welfare reform in general. This is a very common type of bow, one showing mainly red and yellow, with little or no green or blue. Florida is the pivotal state in the nation. He did a good job. They could not ignore the will of parliament, he claimed. What was the main difference? I am totally devoted to this job. We wanted it left for a wee while. Mr Kennedy is not a candidate for the Scottish Parliament. they fail to engage. However, it was well worth the wait. The post will be unpaid. Details of the new vessel were given in London yesterday. That would help. We were surprised to see the photograph. It will decide today whether he should be struck off the register. People look, but no one ever finds it.  Journalists should make him. I saw one body. A search and rescue mission was mounted within minutes. We will push. An appeal against the sentence was dismissed the following year. Police later said the scheme would end in November. We must look forward. I am so upset. What has caused the demise of singing? I got a great response from the players, as I had expected. IT shouldn't come as a surprise, but it does. Suddenly, the rugby world had changed. This is a national crisis. Who will perform? Twaddle is a case in point. We run within the law. Today she has been released. They're appalled by that. Who did the recruiting? Work has started. She said she could not believe that they had run away. It was the same at Twickenham. He was adamant that he was still ahead on everything that matters. Mr Ferguson became a minister after seven years as a journalist. He met Mr Davies to establish the scale of the scandal. I have tonight resigned as a member of the European Commission. The oil compan ...

# %%
for txt in df.normalized_text:
    for word in txt.split(' '):
        if word.upper() == word and len(word) > 1:
            print(txt)
            break

# %%
re.sub('\s\.', '.', 'bbbawef . aaaaa')
# Out:
# 'bbbawef. aaaaa'

# %%
import re

# %%
_RE_REPLACE_PARENTHESIS = (r'[(){}_\[\]]', '')
_RE_REPLACE_QUESTIONMARK = ('\s\?', '?')
_RE_REPLACE_EXCLAMATIONMARK = ('\s\!', '!')
_RE_REPLACE_DOT = ('\s\.', '.')
_RE_COMBINE_WHITESPACE = (r'\s+', ' ')

re_list = [
    _RE_REPLACE_PARENTHESIS,
    _RE_REPLACE_QUESTIONMARK,
    _RE_REPLACE_EXCLAMATIONMARK,
    _RE_REPLACE_DOT,
    _RE_COMBINE_WHITESPACE, 
]


for i, txt in enumerate(df.text):
    retxt = txt
    retxt = retxt.lstrip(' .,?!')
    if retxt[:-1] in ['"', "'"]:
        retxt.strip('\"\'')    
    for pattern, repl in re_list:
        retxt = re.sub(pattern, repl, retxt).strip()
    if txt.count('"') == 1:
        print(txt, retxt, sep='\n', end='\n\n')
    df.loc[i, 'retext'] = retxt

# %%
df
# Out:
#        page     index                                         audio_path  \
# 0      p311  p311_139  /data4/TTS/VCTK/VCTK-Corpus/wav48/p311/p311_13...
# 1      p311  p311_375  /data4/TTS/VCTK/VCTK-Corpus/wav48/p311/p311_37...
# 2      p311  p311_093  /data4/TTS/VCTK/VCTK-Corpus/wav48/p311/p311_09...
# 3      p311  p311_251  /data4/TTS/VCTK/VCTK-Corpus/wav48/p311/p311_25...
# 4      p311  p311_110  /data4/TTS/VCTK/VCTK-Corpus/wav48/p311/p311_11...
# ...     ...       ...                                                ...
# 44065  p316  p316_299  /data4/TTS/VCTK/VCTK-Corpus/wav48/p316/p316_29...
# 44066  p316  p316_374  /data4/TTS/VCTK/VCTK-Corpus/wav48/p316/p316_37...
# 44067  p316  p316_073  /data4/TTS/VCTK/VCTK-Corpus/wav48/p316/p316_07...
# 44068  p316  p316_089  /data4/TTS/VCTK/VCTK-Corpus/wav48/p316/p316_08...
# 44069  p316  p316_333  /data4/TTS/VCTK/VCTK-Corpus/wav48/p316/p316_33...
#
#                                              audio_array  \
# 0      [-0.0062520076, -0.011541563, -0.010065744, -0...
# 1      [-0.00071739114, -0.0012887787, -0.0010795597,...
# 2      [0.0024772577, 0.004634639, 0.0041303067, 0.00...
# 3      [-0.0021431618, -0.0037750585, -0.0032232087, ...
# 4      [0.0016572413, 0.0032106584, 0.0028606544, 0.0...
# ...                                                  ...
# 44065  [0.0013067361, 0.0023353891, 0.0020710027, 0.0...
# 44066  [-0.0013757308, -0.0026514267, -0.0023597914, ...
# 44067  [0.008805143, 0.016143003, 0.014221777, 0.0152...
# 44068  [-0.00470766, -0.0086214105, -0.007555666, -0....
# 44069  [0.0040244935, 0.0075207762, 0.006674729, 0.00...
#
#                                         text  sample_rate  \
# 0                     They got the job done.        16000
# 1                     We don't ask for much.        16000
# 2                        It is set in Paris.        16000
# 3            Mentally, you have to be tough.        16000
# 4      It is not really used by many people.        16000
# ...                                      ...          ...
# 44065           I am quite excited about it.        16000
# 44066      We said it will happen one night.        16000
# 44067               He was also a great man.        16000
# 44068             The driver escaped injury.        16000
# 44069        It is the wealthiest in Europe.        16000
#
#                                       retext
# 0                     They got the job done.
# 1                     We don't ask for much.
# 2                        It is set in Paris.
# 3            Mentally, you have to be tough.
# 4      It is not really used by many people.
# ...                                      ...
# 44065           I am quite excited about it.
# 44066      We said it will happen one night.
# 44067               He was also a great man.
# 44068             The driver escaped injury.
# 44069        It is the wealthiest in Europe.
#
# [44070 rows x 7 columns]
