# %%
import os
import re
import _pickle as cPickle
import gc
import random
from tqdm import tqdm
import numpy as np
import torch

from datasets import load_dataset, load_metric
from evaluate import load


import math
from itertools import groupby

import wandb

DEVICES=['0','1','2']
BATCH_SIZE = 16

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(DEVICES)
# os.environ["WANDB_DISABLED"] = "true"
os.environ["HF_DATASETS_OFFLINE"] = "1"
os.environ["TRANSFORMERS_OFFLINE"] = "1"

cache_dir = "/data4/yoomcache"
model_cache_dir = os.path.join(cache_dir, 'huggingfaces')
data_cache_dir = os.path.join(cache_dir, 'datasets')
checkpoint_dir = os.path.join(cache_dir, 'checkpoint')

seed = 0
random.seed(0)
np.random.seed(seed)
torch.manual_seed(seed)

import IPython
import seaborn as sns
sns.set(rc = {'figure.figsize':(16,9)})

# %%
from wav2vec2GPTwCTC import *
from configuration_wav2vec2gpt import Wav2Vec2GPTConfig

from transformers import Wav2Vec2FeatureExtractor, GPT2Model
from transformers import GPT2Tokenizer, AddedToken
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

# %%
wav2vec_pretrained = "facebook/wav2vec2-base"
# wav2vec_pretrained = "facebook/wav2vec2-base-960h"
gpt_pretrained = "gpt2"

# Should aware that pad_token_id is used to compute CTC loss, 
# so pad_token configuration for both tokenizer and model should be the same
args = {
    
    'pad_token': "<|endoftext|>", 'pad_token_id': 50256,  # 'Ġ' ... 220,
    'unk_token': "<|endoftext|>", 'unk_token_id': 50256,
    'bos_token': "<|endoftext|>", 'bos_token_id': 50256,
    'eos_token': "<|endoftext|>", 'eos_token_id': 50256,
    'ctc_loss_reduction': 'mean',
    
    
    'select_random': True,
    'loss_ver': 'ctc',  # 'ctc-ce', 'ce-ctc', 'ctc', 'ce'
    
    
    'add_adapter': True,
    'num_adapter_layers': 3,
    'output_hidden_size': [128, 256, 512, 256],
    'adapter_kernel_size': [4, 3, 3, 3, 3], 
    'adapter_stride':      [2, 2, 2, 1, 1],
    'adapter_padding':     [4, 0, 0, 0, 0],
    'adapter_bias': False,
    
    
    # Wav2Vec
    'hidden_dropout': 0.0,
    'activation_dropout': 0.0,
    'attention_dropout': 0.0,
    'feat_proj_dropout': 0.0,
    'feat_quantizer_dropout': 0.0,
    'final_dropout': 0.2,
    'layerdrop': 0.0,
    # GPT
    'resid_pdrop': 0.0,
    'embd_pdrop': 0.0,
    'attn_pdrop': 0.0,
    
    
    
}

config = Wav2Vec2GPTConfig(**args)

# %%
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained(wav2vec_pretrained, 
                                                             cache_dir=model_cache_dir,
                                                             **args)

tokenizer = GPT2Tokenizer.from_pretrained(gpt_pretrained,
                                          cache_dir=model_cache_dir,
                                          **args)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Data Loading

# %%
data_dir = '/data4/TTS/'
data_fname = 'VCTK-Corpus/dataset-vctk-16k.pkl'
# data_fname = 'LibriTTS/train-clean-100.pkl'
# data_fname = 'LibriTTS/dev-clean.pkl'

dataset_ratio = 0.5
#########################################################

with open(os.path.join(data_dir, data_fname), 'rb') as f:
    gc.disable()
    dataset = cPickle.load(f)
    gc.enable()
print('entire dataset length: {}'.format(len(dataset['text'])))


dataset_size = int(len(dataset['text']) * dataset_ratio)
for k in dataset.keys():
    if k == 'sample_rate': continue
    del dataset[k][dataset_size:]
print('dataset length: {}'.format(dataset_size))


min_audio_length, max_audio_length = 1e6, 0
for arr in dataset['audio_array']:
    if len(arr) > max_audio_length:
        max_audio_length = len(arr)
    if len(arr) < min_audio_length:
        min_audio_length = len(arr)
print('maximum audio length: {} ({} sec)'.format(max_audio_length, 
                                                 max_audio_length / dataset['sample_rate']))
print('minimum audio length: {} ({} sec)'.format(min_audio_length, 
                                                 min_audio_length / dataset['sample_rate']))
# Out:
# entire dataset length: 44070
# dataset length: 22035
# maximum audio length: 308533 (19.2833125 sec)
# minimum audio length: 13715 (0.8571875 sec)

# %% [markdown]
# ### Data Example

# %%
idx = 11
print('text example: {}'.format(dataset['text'][idx]))
IPython.display.Audio(dataset['audio_array'][idx], rate=16000)
# Out:
# text example: People look, but no one ever finds it.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Audio Preprocessing w/ `Wav2Vec2FeatureExtractor`

# %%
for idx in tqdm(range(dataset_size)):
    dataset['audio_array'][idx] = feature_extractor(dataset['audio_array'][idx], 
                                                    sampling_rate=dataset['sample_rate'],
                                                    return_tensors="pt",
                                                    padding='max_length',
                                                    max_length=max_audio_length
                                                    ).input_values[0]
# Out:
# 100%|████████████████████████████████████| 22035/22035 [00:41<00:00, 525.98it/s]

# %% [markdown]
# ### Text Prepressing and Tokenizing w/ `GPT2Tokenizer`

# %%
_RE_REPLACE_PARENTHESIS = (r'[(){}_\[\]]', '')
_RE_REPLACE_QUESTIONMARK = ('\s\?', '?')
_RE_REPLACE_EXCLAMATIONMARK = ('\s\!', '!')
_RE_REPLACE_DOT = ('\s\.', '.')
_RE_COMBINE_WHITESPACE = (r'\s+', ' ')

re_list = [
    _RE_REPLACE_PARENTHESIS,
    _RE_REPLACE_QUESTIONMARK,
    _RE_REPLACE_EXCLAMATIONMARK,
    _RE_REPLACE_DOT,
    _RE_COMBINE_WHITESPACE, 
]

dataset['retext'] = list()

for txt in dataset['text']:
    retxt = txt
    retxt = retxt.lstrip(' .,?!')
    if retxt[:-1] in ['"', "'"]:
        retxt.strip('\"\'')    
    for pattern, repl in re_list:
        retxt = re.sub(pattern, repl, retxt).strip()
    
    dataset['retext'].append(retxt)

# %%
dataset['text'] = tokenizer(dataset['retext'],
                            return_tensors="pt",
                            padding='longest'  # VCTK: 42, libritts: 92
                            )

print(dataset['text']['attention_mask'].shape)
# Out:
# torch.Size([22035, 41])

# %% [markdown]
# ### Generate Custom Dataset

# %%
split_ratio = (0.8, 0.9)
indices = np.arange(dataset_size)
np.random.shuffle(indices)

train_idx = indices[:int(dataset_size * split_ratio[0])]
val_idx = indices[int(dataset_size * split_ratio[0]):int(dataset_size * split_ratio[1])]
test_idx = indices[int(dataset_size * split_ratio[1]):]

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, input_values, tokenized_output, indices):
        self.input_values = input_values
        self.tokenized_output = tokenized_output
        self.indices = indices

    def __getitem__(self, idx):
        item = dict()
        item['input_values'] = self.input_values[self.indices[idx]]
        item['labels'] = self.tokenized_output['input_ids'][self.indices[idx]]
        item['output_attention_mask'] = self.tokenized_output['attention_mask'][self.indices[idx]]
        return item

    def __len__(self):
        return len(self.indices)

    

train_dataset = CustomDataset(dataset['audio_array'], dataset['text'], train_idx)
# val_dataset = CustomDataset(dataset['audio_array'], dataset['text'], val_idx)
val_dataset = CustomDataset(dataset['audio_array'], dataset['text'], train_idx[:dataset_size // 10])
test_dataset = CustomDataset(dataset['audio_array'], dataset['text'], test_idx)

# %%
model = Wav2Vec2GPTModel(config=config)

model.wav2vec2 = Wav2Vec2Model2.from_pretrained(wav2vec_pretrained, cache_dir=model_cache_dir, config=config)
transformer = GPT2Model.from_pretrained(gpt_pretrained, cache_dir=model_cache_dir, config=config)
model.lm_head.weight = transformer.wte.weight



model.freeze_feature_extractor()
# model.freeze_wav2vec_adapter()
# model.freeze_compressor()
model.freeze_lm_head()
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2Model2: ['wav2vec2.encoder.layers.1.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.6.attention.v_proj.weight', 'wav2vec2.encoder.layers.3.feed_forward.intermediate_dense.weight', 'wav2vec2.encoder.layers.7.feed_forward.intermediate_dense.weight', 'wav2vec2.encoder.layers.0.layer_norm.bias', 'wav2vec2.encoder.layers.6.attention.out_proj.weight', 'wav2vec2.encoder.layer_norm.bias', 'wav2vec2.encoder.layers.4.attention.out_proj.bias', 'wav2vec2.encoder.layers.10.final_layer_norm.bias', 'wav2vec2.encoder.layers.4.attention.v_proj.bias', 'wav2vec2.encoder.layers.9.attention.q_proj.weight', 'wav2vec2.encoder.layers.11.attention.out_proj.weight', 'wav2vec2.encoder.layers.11.attention.q_proj.bias', 'wav2vec2.encoder.layers.4.feed_forward.intermediate_dense.weight', 'wav2vec2.encoder.layers.11.layer_norm.bias', 'wav2vec2.feature_projection.projection.weight', 'wav2vec2.encoder.layers.0.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.3.attention.v_proj.weight', 'wav2vec2.encoder.layers.9.layer_norm.weight', 'wav2vec2.encoder.layers.6.attention.k_proj.weight', 'wav2vec2.encoder.layers.7.attention.out_proj.bias', 'wav2vec2.encoder.layers.8.feed_forward.intermediate_dense.weight', 'wav2vec2.encoder.layers.4.attention.k_proj.bias', 'wav2vec2.encoder.layers.0.layer_norm.weight', 'wav2vec2.encoder.layers.0.feed_forward.intermediate_dense.bias', 'wav2vec2.encoder.layers.1.feed_forward.output_dense.bias', 'wav2vec2.encoder.layers.3.final_layer_norm.bias', 'wav2vec2.encoder.layers.0.attention.q_proj.bias', 'wav2vec2.encoder.layers.10.attention.out_proj.weight', 'wav2vec2.encoder.layers.4.feed_forward.intermediate_dense.bias', 'wav2vec2.encoder.layers.3.feed_forward.intermediate_dense.bias', 'wav2vec2.encoder.layers.11.feed_forward.output_dense.bias', 'wav2vec2.encoder.layers.1.attention.v_proj.bias', 'wav2vec2.encoder.layers.11.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.11.layer_norm.weight', 'wav2vec2.encoder.layers.4.attention.q_proj.weight', 'wav2vec2.encoder.layers.9.final_layer_norm.bias', 'wav2vec2.encoder.layers.2.feed_forward.intermediate_dense.weight', 'wav2vec2.encoder.layers.3.layer_norm.bias', 'wav2vec2.encoder.layers.4.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.3.attention.k_proj.weight', 'wav2vec2.encoder.layers.4.attention.k_proj.weight', 'wav2vec2.encoder.layers.6.attention.q_proj.weight', 'wav2vec2.encoder.layers.8.attention.k_proj.bias', 'wav2vec2.encoder.layers.8.layer_norm.weight', 'wav2vec2.encoder.layers.4.attention.q_proj.bias', 'wav2vec2.encoder.layers.5.layer_norm.bias', 'wav2vec2.encoder.layers.9.feed_forward.intermediate_dense.weight', 'wav2vec2.encoder.layers.10.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.6.attention.q_proj.bias', 'wav2vec2.encoder.layers.1.attention.k_proj.weight', 'wav2vec2.encoder.layers.7.attention.v_proj.weight', 'wav2vec2.encoder.layers.0.final_layer_norm.bias', 'wav2vec2.encoder.layers.9.attention.k_proj.weight', 'wav2vec2.encoder.layers.2.attention.out_proj.weight', 'wav2vec2.encoder.layers.2.attention.out_proj.bias', 'wav2vec2.encoder.layers.10.feed_forward.output_dense.bias', 'wav2vec2.encoder.layers.7.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.0.attention.q_proj.weight', 'wav2vec2.encoder.layers.2.attention.k_proj.weight', 'wav2vec2.encoder.layers.2.final_layer_norm.weight', 'wav2vec2.encoder.layers.10.attention.v_proj.bias', 'wav2vec2.encoder.layers.4.feed_forward.output_dense.bias', 'wav2vec2.masked_spec_embed', 'wav2vec2.encoder.layers.5.final_layer_norm.bias', 'wav2vec2.encoder.layers.7.attention.out_proj.weight', 'wav2vec2.encoder.layers.2.attention.q_proj.bias', 'wav2vec2.encoder.layers.2.feed_forward.output_dense.weight', 'wav2vec2.encoder.layers.8.attention.q_proj.bias', 'wav2vec2.encoder.layers.8.final_layer_norm.weight', 'wav2vec2.encoder.layers.6.feed_forward.output_dense.bias', 'wav2vec2 ...
# - This IS expected if you are initializing Wav2Vec2Model2 from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model2 from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2Model2 were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['wav2vec2.adapter.layers.1.conv.weight', 'wav2vec2.adapter.layers.2.conv.weight', 'wav2vec2.adapter.layers.0.conv.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(model)
# Out:
# Wav2Vec2GPTModel(
#   (wav2vec2): Wav2Vec2Model2(
#     (feature_extractor): Wav2Vec2FeatureEncoder(
#       (conv_layers): ModuleList(
#         (0): Wav2Vec2GroupNormConvLayer(
#           (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,), bias=False)
#           (activation): GELUActivation()
#           (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         )
#         (1): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (2): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (3): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (4): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (5): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (6): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#       )
#     )
#     (adapter): Wav2Vec2Adapter(
#       (layers): ModuleList(
#         (0): Wav2Vec2AdapterLayer(
#           (conv): Conv1d(512, 256, kernel_size=(4,), stride=(2,), padding=(4,), bias=False)
#         )
#         (1): Wav2Vec2AdapterLayer(
#           (conv): Conv1d(128, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (2): Wav2Vec2AdapterLayer(
#           (conv): Conv1d(256, 1024, kernel_size=(3,), stride=(2,), bias=False)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (compressor): Conv1d(512, 768, kernel_size=(3,), stride=(1,))
#   (attn): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=6144, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=6144, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# load rouge for validation
rouge = load_metric("rouge")  # pip install rouge
wer = load("wer")  # pip install jiwer

def compute_metrics(pred):
    labels_ids = pred.label_ids
    pred_ids = pred.predictions.argmax(axis=-1)
    
    ### only distinct ones
    pred_ids = [[key for key, _group in groupby(i)] for i in pred_ids]

    ### all unnecessary tokens are removed
    label_str = tokenizer.batch_decode(labels_ids, skip_special_tokens=True)
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)

    rouge_output = rouge.compute(predictions=pred_str, references=label_str, 
                                   rouge_types=["rouge2"])['rouge2'].mid
    wer_score = wer.compute(predictions=pred_str, references=label_str)
    
    return {
        "wer_score": round(wer_score, 4),
        "rouge2_precision": round(rouge_output.precision, 4),
        "rouge2_recall": round(rouge_output.recall, 4),
        "rouge2_fmeasure": round(rouge_output.fmeasure, 4),
    }

# %%
### set training arguments - these params are not really tuned, feel free to change ###

steps_per_epoch = math.ceil(len(train_dataset) / BATCH_SIZE / len(DEVICES))

training_args = Seq2SeqTrainingArguments(
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    learning_rate=1e-3, 
    weight_decay=0.0, adam_beta1=0.9, adam_beta2=0.999, adam_epsilon=1e-08, max_grad_norm=1.0,
    num_train_epochs=50,
    max_steps=-1,
    lr_scheduler_type="cosine", 
    
    logging_strategy='steps',
    logging_steps=int(steps_per_epoch / 10),
    evaluation_strategy='epoch',
    eval_steps=1,
    warmup_steps=int(steps_per_epoch * 10),

    output_dir=os.path.join(checkpoint_dir, "wav2vec2gpt/freeze-adapter-rnn"),
    # save_strategy='steps',
    # save_steps=int(steps_per_epoch * 1),
    save_total_limit=3,
    overwrite_output_dir=True,
    
    eval_accumulation_steps=4,

)

# %%
# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# %%
##### start training #####
wandb.init(project="testing-wav2vec2gpt-221123", entity="yoom618") # 2f747faa5c3ba7aa67c3aa9a68f060bf273d26ba
torch.cuda.empty_cache()

trainer.train()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: yoom618. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/yoomin/ASR-w-GPT/wandb/run-20221203_142452-2s2jg3al</code>
# Syncing run <strong><a href="https://wandb.ai/yoom618/testing-wav2vec2gpt-221123/runs/2s2jg3al" target="_blank">glad-lion-158</a></strong> to <a href="https://wandb.ai/yoom618/testing-wav2vec2gpt-221123" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running training *****
#   Num examples = 17628
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 48
#   Gradient Accumulation steps = 1
#   Total optimization steps = 18400
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='18400' max='18400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18400/18400 6:50:55, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Score</th>
#       <th>Rouge2 Precision</th>
#       <th>Rouge2 Recall</th>
#       <th>Rouge2 Fmeasure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.774900</td>
#       <td>11.774001</td>
#       <td>0.964300</td>
#       <td>0.035600</td>
#       <td>0.007800</td>
#       <td>0.012400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.594500</td>
#       <td>4.605823</td>
#       <td>0.788800</td>
#       <td>0.162500</td>
#       <td>0.083000</td>
#       <td>0.105800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.887100</td>
#       <td>3.514393</td>
#       <td>0.705600</td>
#       <td>0.228600</td>
#       <td>0.156100</td>
#       <td>0.180200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.347200</td>
#       <td>2.806976</td>
#       <td>0.635500</td>
#       <td>0.305800</td>
#       <td>0.227000</td>
#       <td>0.254600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.759500</td>
#       <td>2.671692</td>
#       <td>0.590200</td>
#       <td>0.375300</td>
#       <td>0.285900</td>
#       <td>0.317500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.387700</td>
#       <td>1.839164</td>
#       <td>0.462100</td>
#       <td>0.470200</td>
#       <td>0.435400</td>
#       <td>0.447500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.011500</td>
#       <td>1.429500</td>
#       <td>0.403200</td>
#       <td>0.550200</td>
#       <td>0.515400</td>
#       <td>0.527500</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.765000</td>
#       <td>1.045198</td>
#       <td>0.337500</td>
#       <td>0.606400</td>
#       <td>0.570300</td>
#       <td>0.583400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.593200</td>
#       <td>0.878218</td>
#       <td>0.303200</td>
#       <td>0.637400</td>
#       <td>0.615600</td>
#       <td>0.622600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.440700</td>
#       <td>0.771196</td>
#       <td>0.280600</td>
#       <td>0.677700</td>
#       <td>0.627100</td>
#       <td>0.646800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.234100</td>
#       <td>0.611755</td>
#       <td>0.228300</td>
#       <td>0.728100</td>
#       <td>0.730000</td>
#       <td>0.726300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.016200</td>
#       <td>0.522312</td>
#       <td>0.204500</td>
#       <td>0.778700</td>
#       <td>0.737500</td>
#       <td>0.754100</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.868800</td>
#       <td>0.412352</td>
#       <td>0.168300</td>
#       <td>0.813500</td>
#       <td>0.794500</td>
#       <td>0.801300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.789700</td>
#       <td>0.329467</td>
#       <td>0.132100</td>
#       <td>0.853100</td>
#       <td>0.851700</td>
#       <td>0.850600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.686200</td>
#       <td>0.318499</td>
#       <td>0.132000</td>
#       <td>0.862500</td>
#       <td>0.838300</td>
#       <td>0.848000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.596200</td>
#       <td>0.237576</td>
#       <td>0.097600</td>
#       <td>0.896800</td>
#       <td>0.900500</td>
#       <td>0.897200</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.523100</td>
#       <td>0.219867</td>
#       <td>0.088600</td>
#       <td>0.898800</td>
#       <td>0.902800</td>
#       <td>0.899700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.451400</td>
#       <td>0.202443</td>
#       <td>0.086300</td>
#       <td>0.916900</td>
#       <td>0.901400</td>
#       <td>0.907700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.408100</td>
#       <td>0.152993</td>
#       <td>0.068200</td>
#       <td>0.932900</td>
#       <td>0.935400</td>
#       <td>0.933100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.365300</td>
#       <td>0.135315</td>
#       <td>0.057800</td>
#       <td>0.943300</td>
#       <td>0.944000</td>
#       <td>0.942800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.322100</td>
#       <td>0.130862</td>
#       <td>0.056700</td>
#       <td>0.945100</td>
#       <td>0.948200</td>
#       <td>0.945800</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.281600</td>
#       <td>0.113928</td>
#       <td>0.048600</td>
#       <td>0.953200</td>
#       <td>0.955200</td>
#       <td>0.953600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.275400</td>
#       <td>0.093595</td>
#       <td>0.038700</td>
#       <td>0.967300</td>
#       <td>0.965700</td>
#       <td>0.966100</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.223800</td>
#       <td>0.076143</td>
#       <td>0.034100</td>
#       <td>0.970000</td>
#       <td>0.967700</td>
#       <td>0.968500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.190600</td>
#       <td>0.074412</td>
#       <td>0.030300</td>
#       <td>0.975700</td>
#       <td>0.974300</td>
#       <td>0.974600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.181700</td>
#       <td>0.053377</td>
#       <td>0.026200</td>
#       <td>0.981500</td>
#       <td>0.979100</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.156200</td>
#       <td>0.055566</td>
#       <td>0.024300</td>
#       <td>0.984500</td>
#       <td>0.980800</td>
#       <td>0.982500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.133700</td>
#       <td>0.048286</td>
#       <td>0.018800</td>
#       <td>0.988700</td>
#       <td>0.988400</td>
#       <td>0.988400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.112300</td>
#       <td>0.044301</td>
#       <td>0.017200</td>
#       <td>0.990600</td>
#       <td>0.990200</td>
#       <td>0.990300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.102700</td>
#       <td>0.035194</td>
#       <td>0.015600</td>
#       <td>0.992400</td>
#       <td>0.991400</td>
#       <td>0.991700</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.079400</td>
#       <td>0.037929</td>
#       <td>0.014700</td>
#       <td>0.993400</td>
#       <td>0.991500</td>
#       <td>0.992300</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.069100</td>
#       <td>0.026690</td>
#       <td>0.011100</td>
#       <td>0.995600</td>
#       <td>0.995300</td>
#       <td>0.995400</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.050300</td>
#       <td>0.021208</td>
#       <td>0.009900</td>
#       <td>0.996000</td>
#       <td>0.994900</td>
#       <td>0.995300</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.047700</td>
#       <td>0.019177</td>
#       <td>0.009500</td>
#       <td>0.997000</td>
#       <td>0.996500</td>
#       <td>0.996700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.048700</td>
#       <td>0.017658</td>
#       <td>0.009300</td>
#       <td>0.997100</td>
#       <td>0.996500</td>
#       <td>0.996800</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.032300</td>
#       <td>0.020167</td>
#       <td>0.008500</td>
#       <td>0.997700</td>
#       <td>0.996800</td>
#       <td>0.997200</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.024800</td>
#       <td>0.020758</td>
#       <td>0.006900</td>
#       <td>0.997700</td>
#       <td>0.997300</td>
#       <td>0.997500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.021200</td>
#       <td>0.014259</td>
#       <td>0.007100</td>
#       <td>0.998200</td>
#       <td>0.997500</td>
#       <td>0.997800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.020100</td>
#       <td>0.013883</td>
#       <td>0.006500</td>
#       <td>0.998500</td>
#       <td>0.997700</td>
#       <td>0.997900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.021100</td>
#       <td>0.013847</td>
#       <td>0.006600</td>
#       <td>0.998300</td>
#       <td>0.997800</td>
#       <td>0.998000</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.026300</td>
#       <td>0.011357</td>
#       <td>0.006300</td>
#       <td>0.998100</td>
#       <td>0.997700</td>
#       <td>0.997900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.013800</td>
#       <td>0.010350</td>
#       <td>0.006200
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-18000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-1500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-2500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-3500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-4500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-5500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-6500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-7500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-8500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-9500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-10500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-11500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-12500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-13500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-14500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-15500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17500
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17500/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-17500/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16000] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# Saving model checkpoint to /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-18000
# Configuration saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-18000/config.json
# Model weights saved in /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-16500] due to args.save_total_limit
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/yoomin/anaconda3/envs/py38/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 0 which
#     has less than 75% of the memory or cores of GPU 2. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
# ***** Running Evaluation *****
#   Num examples = 2203
#   Batch size = 48
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=18400, training_loss=0.9241408855970139, metrics={'train_runtime': 24663.9837, 'train_samples_per_second': 35.736, 'train_steps_per_second': 0.746, 'total_flos': 9.34853225171493e+19, 'train_loss': 0.9241408855970139, 'epoch': 50.0})

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.005 MB of 0.005 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/rouge2_fmeasure</td><td>▁▂▂▃▄▅▅▅▆▆▇▇▇▇▇█████████████████████████</td></tr><tr><td>eval/rouge2_precision</td><td>▁▂▂▃▄▅▅▅▆▆▇▇▇▇▇█████████████████████████</td></tr><tr><td>eval/rouge2_recall</td><td>▁▂▂▃▄▅▅▅▆▆▇▇▇▇▇█████████████████████████</td></tr><tr><td>eval/runtime</td><td>▂▂▂▁▂▃▃▄▅▅▆▅▆▆▅▅▅▆▅▆▅▆▅▆▅▅▆▆▆▅▅▅▃▆▆▆▄▅▇█</td></tr><tr><td>eval/samples_per_second</td><td>▇▆▇█▇▅▅▄▄▃▃▃▃▃▄▃▃▃▃▃▃▃▄▃▃▃▃▃▃▃▄▄▅▂▃▂▄▄▁▁</td></tr><tr><td>eval/steps_per_second</td><td>▇▆▇█▇▅▅▄▄▃▃▃▃▃▄▃▃▃▃▃▃▃▄▃▃▃▃▃▃▃▄▄▅▂▃▂▄▄▁▁</td></tr><tr><td>eval/wer_score</td><td>█▇▆▆▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/learning_rate</td><td>▁▂▃▄▅▆▆▇██████▇▇▇▇▆▆▆▅▅▅▄▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▅▅▄▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.00792</td></tr><tr><td>eval/rouge2_fmeasure</td><td>0.9981</td></tr><tr><td>eval/rouge2_precision</td><td>0.9984</td></tr><tr><td>eval/rouge2_recall</td><td>0.9978</td></tr><tr><td>eval/runtime</td><td>332.3728</td></tr><tr><td>eval/samples_per_second</td><td>6.628</td></tr><tr><td>eval/steps_per_second</td><td>0.138</td></tr><tr><td>eval/wer_score</td><td>0.0057</td></tr><tr><td>train/epoch</td><td>50.0</td></tr><tr><td>train/global_step</td><td>18400</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0079</td></tr><tr><td>train/total_flos</td><td>9.34853225171493e+19</td></tr><tr><td>train/train_loss</td><td>0.92414</td></tr><tr><td>train/train_runtime</td><td>24663.9837</td></tr><tr><td>train/train_samples_per_second</td><td>35.736</td></tr><tr><td>train/train_steps_per_second</td><td>0.746</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glad-lion-158</strong>: <a href="https://wandb.ai/yoom618/testing-wav2vec2gpt-221123/runs/2s2jg3al" target="_blank">https://wandb.ai/yoom618/testing-wav2vec2gpt-221123/runs/2s2jg3al</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221203_142452-2s2jg3al/logs</code>

# %%
# !ls /data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn

# model.load_state_dict(torch.load('/data4/yoomcache/checkpoint/wav2vec2gpt/freeze-adapter-rnn/checkpoint-18000/pytorch_model.bin'))
# Out:
# checkpoint-17000  checkpoint-17500  checkpoint-18000  runs

# %%
##### example


BATCH_SIZE = 4
i = 3
device = 'cuda:0'
batch_idx = train_idx[i*BATCH_SIZE:i*BATCH_SIZE+BATCH_SIZE]

audio_feature_batch = list()
for idx in batch_idx:
    audio_feature_batch.append(dataset['audio_array'][idx])
audio_feature_batch = torch.stack(audio_feature_batch)

label_batch = dataset['text']['input_ids'][batch_idx]
attention_batch = dataset['text']['attention_mask'][batch_idx]

with torch.no_grad():
    model.eval()
    pred_logits = model(input_values=audio_feature_batch.to(device), ).logits
    pred_ids = pred_logits.argmax(dim=-1)
    
    for idx in range(BATCH_SIZE):
        print(len([key for key, _group in groupby(label_batch[idx])]))
        print(tokenizer.decode([key for key, _group in groupby(label_batch[idx])],skip_special_tokens=True))
        print()
        print(tokenizer.decode([key for key, _group in groupby(pred_ids[idx])],skip_special_tokens=True))
        print()
        print(tokenizer.decode(pred_ids[idx]))
        print()
        print()
# Out:
# 12
# The output price index in December was unchanged on November.
#
# The output price index in December was unchanged on November.
#
# <|endoftext|><|endoftext|>The output<|endoftext|> price<|endoftext|><|endoftext|> index in in December<|endoftext|><|endoftext|> was<|endoftext|><|endoftext|> unchanged<|endoftext|> on<|endoftext|> November<|endoftext|><|endoftext|><|endoftext|>.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
#
#
# 13
# Throughout the centuries people have explained the rainbow in various ways.
#
# Throughout the centuries people have explained the rainbow in various ways.
#
# <|endoftext|><|endoftext|>Throughout<|endoftext|><|endoftext|> the<|endoftext|> centuries<|endoftext|> people people have have<|endoftext|> explained the rainbow in various various<|endoftext|> ways<|endoftext|><|endoftext|><|endoftext|>.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
#
#
# 9
# Whoever said that cannot have seen it.
#
# Whoever said that cannot have seen it.
#
# <|endoftext|><|endoftext|><|endoftext|>Whoever<|endoftext|><|endoftext|> said<|endoftext|> that<|endoftext|> cannot<|endoftext|><|endoftext|><|endoftext|> have<|endoftext|> seen<|endoftext|> it<|endoftext|><|endoftext|>.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
#
#
# 9
# We have reports of this throughout Scotland.
#
# We have reports of this throughout Scotland.
#
# <|endoftext|>WeWe have<|endoftext|><|endoftext|> reports of this throughout<|endoftext|><|endoftext|> Scotland<|endoftext|><|endoftext|><|endoftext|>.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>

# %%
wer.compute(references=['Throughout the centuries people have explained the rainbow in various ways.'],
            predictions=['Throughout the centuries people have explained rainbow in various.'])
# Out:
# 0.2727272727272727

# %%
idx = 1

with torch.no_grad():
    model.eval()
    hidden_states_wav = model.wav2vec2(audio_feature_batch.to(device)).last_hidden_state
    hidden_states_wav = model.compressor(hidden_states_wav.transpose(1,2)).transpose(1,2)
    hidden_states_wav = model.attn(hidden_states_wav)
        
    sns.heatmap(
        nn.functional.softmax(model.lm_head(hidden_states_wav), dim=2).cpu()[idx,:, :1000]
    )
    

IPython.display.Audio(dataset['audio_array'][batch_idx[idx]], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
